# %%
# !pip install vaderSentiment

# %%
#importing libraries 

import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
pd.set_option('display.max_columns',150)
pd.set_option('display.max_rows',1500)

# %%
filepath = '../datasets/AmericanAir.csv'
american = pd.read_csv(filepath)
display(american.head())
american.shape
# Out:
#                     id      conversation_id     created_at        date  \
# 0  1100908059474440193  1100908059474440193  1551311909000  2019-02-28
# 1  1100907529117335553  1100903984615825409  1551311783000  2019-02-28
# 2  1100907238720335872  1100907238720335872  1551311714000  2019-02-28
# 3  1100906955374247937  1100906955374247937  1551311646000  2019-02-28
# 4  1100906933534556165  1100906933534556165  1551311641000  2019-02-28
#
#        time                       timezone     user_id        username  \
# 0  07:58:29  Malay Peninsula Standard Time   327016620         evansyp
# 1  07:56:23  Malay Peninsula Standard Time    22536055     americanair
# 2  07:55:14  Malay Peninsula Standard Time    31359161          arekcl
# 3  07:54:06  Malay Peninsula Standard Time   574044267  trudymsullivan
# 4  07:54:01  Malay Peninsula Standard Time  1875853351         kjs3964
#
#                 name  place  \
# 0             Greigh    NaN
# 1  American Airlines    NaN
# ...

# %%
# american[american['username']=='americanair']

# %%
airline_replies = american[american['username']=='americanair'].index

# %%
american.drop(index=airline_replies, inplace=True)
american.reset_index(drop=True,inplace=True)

# %%
american
# Out:
#                      id      conversation_id     created_at        date  \
# 0   1100908059474440193  1100908059474440193  1551311909000  2019-02-28
# 1   1100907238720335872  1100907238720335872  1551311714000  2019-02-28
# 2   1100906955374247937  1100906955374247937  1551311646000  2019-02-28
# 3   1100906933534556165  1100906933534556165  1551311641000  2019-02-28
# 4   1100906634585477120  1100906634585477120  1551311570000  2019-02-28
# 5   1100906217063493633  1100906217063493633  1551311470000  2019-02-28
# 6   1100906127842312192  1100882082505654273  1551311449000  2019-02-28
# 7   1100906066974527490  1100880434311897089  1551311434000  2019-02-28
# 8   1100905954365919232  1100904283158073345  1551311408000  2019-02-28
# 9   1100905656008224769  1100850818406731777  1551311336000  2019-02-28
# 10  1100905602824364032  1100880113506443265  1551311324000  2019-02-28
# 11  1100905521035530240  1100835835883048960  1551311304000  2019-02-28
# ...

# %%
american.shape
# Out:
# (64, 34)

# %%
df = american[['tweet']]

# %%
american['tweet'][0]
# Out:
# 'Hey @AmericanAir ! How is a round trip to Rome $1900 but when I make it just one way, the same exact flight is $3,670'

# %%
vs = SentimentIntensityAnalyzer()

# %%
score = vs.polarity_scores('Hey @AmericanAir ! How is a round trip to Rome $1900 but when I make it just one way, the same exact flight is $3,670')
score
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
score['compound']
# Out:
# 0.0

# %%
df['vader_analysis'] = [vs.polarity_scores(text)['compound'] for text in df['tweet']]
# Out:
# C:\Users\leanne\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['vader_analysis']
# Out:
# 0     0.0000
# 1     0.0000
# 2    -0.4936
# 3     0.2120
# 4     0.2905
# 5     0.3147
# 6    -0.3400
# 7     0.0000
# 8     0.0000
# 9     0.6988
# 10   -0.2960
# 11    0.0000
# 12   -0.4740
# 13    0.9153
# 14    0.0000
# 15    0.7717
# 16    0.4767
# 17    0.0000
# 18   -0.4215
# 19   -0.6962
# 20    0.6597
# 21   -0.5104
# 22    0.0000
# 23    0.1506
# 24    0.0000
# 25   -0.5106
# 26    0.0000
# 27    0.0000
# 28   -0.5423
# 29    0.9508
# 30    0.9353
# 31   -0.4019
# 32    0.9606
# 33    0.4574
# 34    0.3839
# 35   -0.3400
# 36    0.0000
# 37   -0.7671
# 38   -0.6249
# 39   -0.2960
# 40   -0.4767
# 41    0.0000
# 42   -0.4215
# 43   -0.2755
# 44    0.0000
# 45    0.0000
# 46    0.2960
# 47   -0.7639
# 48   -0.3818
# 49   -0.3612
# 50   -0.5551
# 51    0.0000
# 52    0.9686
# 53    0.4404
# 54    0.0000
# 55    0.6792
# 56   -0.5664
# 57    0.3336
# 58    0.6249
# 59   -0.5095
# 60   -0.1781
# 61    0.1690
# 62    0.3400
# 63    0.0000
# Name: vader_analysis, dtype: float64

# %%
df.vader_analysis[0]
# Out:
# 0.0

# %%
sentiment = []
for i in df['vader_analysis']:
    if i >=0.05:
        sentiment.append(2)
    elif i <=-0.05:
        sentiment.append(0)
    else:
        sentiment.append(1)
        
        
df['airline_sentiment'] = sentiment
# Out:
# C:\Users\leanne\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
df
# Out:
#                                                 tweet  vader_analysis  \
# 0   Hey @AmericanAir ! How is a round trip to Rome...          0.0000
# 1   I’ve never seen this livery on the A319 before...          0.0000
# 2   Not much better than an @AmericanAir #windowse...         -0.4936
# 3   @AmericanAir few days ago I booked two first c...          0.2120
# 4   @AmericanAir I could choose preferred seats on...          0.2905
# 5   No new news here... thanks @AmericanAir for sa...          0.3147
# 6   Just so you know: we haven’t moved for two and...         -0.3400
# 7    https://www.transportation.gov/airconsumer/fi...          0.0000
# 8                          pic.twitter.com/FMop2jrQp6          0.0000
# 9   It CAN be done! Love this! Way to go @American...          0.6988
# 10  I had a horrible gate agent in Charlotte. She ...         -0.2960
# 11   https://www.transportation.gov/airconsumer/fi...          0.0000
# ...

# %%
df.to_csv('../datasets/aa_tweets.csv', index=False)

# %%
# df['airline_sentiment'] = [2 for i in df['vader_analysis'] if i >= 0.05 else 0 if i <=-0.05 else 1]

# %%
filepath = '../datasets/AmericanAir_2.csv'
american_2019 = pd.read_csv(filepath)
display(american_2019.head())
american_2019.shape
# Out:
#                     id      conversation_id     created_at        date  \
# 0  1100908059474440193  1100908059474440193  1551311909000  2019-02-28
# 1  1100907529117335553  1100903984615825409  1551311783000  2019-02-28
# 2  1100907238720335872  1100907238720335872  1551311714000  2019-02-28
# 3  1100906955374247937  1100906955374247937  1551311646000  2019-02-28
# 4  1100906933534556165  1100906933534556165  1551311641000  2019-02-28
#
#        time                       timezone     user_id        username  \
# 0  07:58:29  Malay Peninsula Standard Time   327016620         evansyp
# 1  07:56:23  Malay Peninsula Standard Time    22536055     americanair
# 2  07:55:14  Malay Peninsula Standard Time    31359161          arekcl
# 3  07:54:06  Malay Peninsula Standard Time   574044267  trudymsullivan
# 4  07:54:01  Malay Peninsula Standard Time  1875853351         kjs3964
#
#                 name  place  \
# 0             Greigh    NaN
# 1  American Airlines    NaN
# ...

# %%
airline_replies = american_2019[american_2019['username']=='americanair'].index

# %%
american_2019.drop(index=airline_replies, inplace=True)
american_2019.reset_index(drop=True,inplace=True)

# %%
american_2019
# Out:
#                       id      conversation_id     created_at        date  \
# 0    1100908059474440193  1100908059474440193  1551311909000  2019-02-28
# 1    1100907238720335872  1100907238720335872  1551311714000  2019-02-28
# 2    1100906955374247937  1100906955374247937  1551311646000  2019-02-28
# 3    1100906933534556165  1100906933534556165  1551311641000  2019-02-28
# 4    1100906634585477120  1100906634585477120  1551311570000  2019-02-28
# 5    1100906217063493633  1100906217063493633  1551311470000  2019-02-28
# 6    1100906127842312192  1100882082505654273  1551311449000  2019-02-28
# 7    1100906066974527490  1100880434311897089  1551311434000  2019-02-28
# 8    1100905954365919232  1100904283158073345  1551311408000  2019-02-28
# 9    1100905656008224769  1100850818406731777  1551311336000  2019-02-28
# 10   1100905602824364032  1100880113506443265  1551311324000  2019-02-28
# 11   1100905521035530240  1100835835883048960  1551311304000  2019-02-28
# ...

# %%
df_2 = american_2019['tweet']

# %%
df_2
# Out:
# 0      Hey @AmericanAir ! How is a round trip to Rome...
# 1      I’ve never seen this livery on the A319 before...
# 2      Not much better than an @AmericanAir #windowse...
# 3      @AmericanAir few days ago I booked two first c...
# 4      @AmericanAir I could choose preferred seats on...
# 5      No new news here... thanks @AmericanAir for sa...
# 6      Just so you know: we haven’t moved for two and...
# 7       https://www.transportation.gov/airconsumer/fi...
# 8                             pic.twitter.com/FMop2jrQp6
# 9      It CAN be done! Love this! Way to go @American...
# 10     I had a horrible gate agent in Charlotte. She ...
# 11      https://www.transportation.gov/airconsumer/fi...
# 12     Just had the most ridiculous call with AA cust...
# 13     Wow, thanks for that amazing response. I’m sur...
# 14     Close, American but they look really similar a...
# 15     Wednesday evening homeless outreach to n #Slou...
# ...
